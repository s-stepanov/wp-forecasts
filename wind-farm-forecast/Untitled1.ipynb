# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

v_in_vector = np.arange(0, v_in, 0.001)
v_p_vector = np.arange(v_in+0.001, v_r, 0.001)
v_max_vector = np.arange(v_r+0.001, v_out, 0.001)
v_out_vector = np.arange(v_out+0.001, 30, 0.001)

P_r = 1

v_in = 2
v_r = 15
v_out = 25

# v_p0 = np.where((v < v_in) | (v > v_out), 0, v)

y_in_values = 0 * v_in_vector
y_p_values = P_r * np.power(((v_p_vector - v_in) / (v_r - v_in)), 2.5)
y_max_values = np.power(v_max_vector, 0)
y_out_values = 0 * v_out_vector

x = np.append(np.append(np.append(v_in_vector, v_p_vector), v_max_vector), v_out_vector)
y = np.append(np.append(np.append(y_in_values, y_p_values), y_max_values), y_out_values)

plt.plot(x, y)
matplotlib.rcParams.update({'font.size': 14})
plt.rcParams["figure.figsize"] = (8, 9)

plt.xlabel('Скорость ветра (м/с)')
plt.ylabel('Мощность (МВт)')
# Out:
# Text(0, 0.5, 'Мощность (МВт)')
